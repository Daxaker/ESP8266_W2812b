# %%
import paho.mqtt.publish as publish

# %%
publish.single("inTopic", 1)

# %%
publish.single("inTopic", 0)

# %%
bytes = b"xyz"

# %%
publish.single("inTopic", bytes)

# %%
bytes = b'El ni\xc3\xb1o come camar\xc3\xb3n'

# %%
bytes([15, 15, 255, 255, 255])
# Out:
# b'\x0f\x0f\xff\xff\xff'

# %%
publish.single("inTopic", 0)

# %%
publish.single("ledMatrix/xy", bytes([1,0, 0,0,0]))

# %%
for x in range(16):
    for y in range(16):
        publish.single("ledMatrix", bytes([x,y, 0,0,0]))

# %%
4 // 3 % 16
# Out:
# 1

# %%
publish.single("ledMatrix/blob", bytes([0,128,0,255,0,0,0,255,0,0,0,0]))

# %%
byteArr = bytearray()

# %%
for x in range(img.size[0]):
    for y in range(img.size[1]):
        rgb = bytes(img.getpixel((x,y)))
        byteArr.append(rgb[0])
        byteArr.append(rgb[1])
        byteArr.append(rgb[2])

# %%
bytes(byteArr)
# Out:
# b")|\x19I\xda,!b\x14\x00\x00\x00\x02\x05\x01\x00\x00\x00\x03\x00\x00\x00\x00\x00\xba\x12\x12\xff\x1c\x1c\xf3\x18\x18\xff\x1b\x1b\xd9\x15\x15\x00\x00\x00\x00\x02\x00\x00\x00\x00+\x81\x1a@\xc0'@\xc0',\x83\x1a\x00\x00\x00\x01\x02\x00\x00\x00\x00\xd0\x17\x14\xff\x0e\x1c\xfaV\x16\xff\xa3\x13\xfcg\x15\xff\x10\x1b\xf4\x19\x18\x0b\x01\x01\x00\x00\x00\x05\x06\x01\x00\x00\x00\x18H\x0fH\xd7+/\x8d\x1c\x00\x00\x00\x00\x00\x00\xd0\x0e\x15\xffa\x18\xfa\xd1\x12\xff\xff\x12\xfc\xde\x12\xffq\x16\xf4\x15\x18
# ...

# %%
img.size
# Out:
# (16, 16)

# %%
publish.single("ledMatrix/blob", bytes(byteArr))

# %%
len(byteArr)
# Out:
# 768

# %%
img.resize((16,16), Image.ANTIALIAS)
# Out:
# <PIL.Image.Image image mode=RGB size=16x16 at 0x10D8310F0>

# %%
img = img.resize((16,16), Image.ANTIALIAS)

# %%
mImg = Image.open("/Users/daxaker/Downloads/mario.ico")

# %%
mImg.size
# Out:
# (16, 16)

# %%
mImg = mImg.resize((16,16), Image.ANTIALIAS)

# %%
for x in range(mImg.size[0]):
    for y in range(mImg.size[1]):
        rgb = bytes(mImg.getpixel((x,y)))
        byteArr.append(rgb[0])
        byteArr.append(rgb[1])
        byteArr.append(rgb[2])
